# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("kc_house_data.csv")
data.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
price=data['price'].values
grade=data['grade'].values
floors=data['floors'].values
bedrooms=data['bedrooms'].values
sqft_living=data['sqft_living'].values

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(price,bedrooms,sqft_living,floors,bedrooms, color="#ef1234")
plt.show()
# Out:
# /home/paa/anaconda3/envs/paa/lib/python3.6/site-packages/mpl_toolkits/mplot3d/art3d.py:794: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if zdir == 'x':
# /home/paa/anaconda3/envs/paa/lib/python3.6/site-packages/mpl_toolkits/mplot3d/art3d.py:796: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   elif zdir == 'y':

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

x=np.array([grade,sqft_living,floors,bedrooms]).T
y=np.array(price)

# %%
reg=LinearRegression()
reg=reg.fit(x,y)
y_pred=reg.predict(x)

rmse=np.sqrt(mean_squared_error(y,y_pred))
r2=reg.score(x,y)
print(rmse)
print(r2)
# Out:
# 247556.69602383225
# 0.5452880848624858

# %%
print(reg.coef_)
print(reg.intercept_)
# Out:
# [100845.13356945    215.88202401 -43169.05455841 -42320.82310102]
# -473918.52347446023

# %%
grade2=6
floors2=3
bedrooms2=1
sqft_living2=10000
data2=np.array([grade2,sqft_living2,floors2,bedrooms2]).T
data2=data2.reshape(1,-1)
price2=print("your home price is:"+str(reg.predict(data2)))
# Out:
# your home price is:[2118144.53130051]
